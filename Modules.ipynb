# %%
# import test_module # importing module with full name
# import test_module as tm # importing module as an alias
# from test_module import find_index # using only the functions you want, does not import anything else
# from test_module import find_index,test # using only the functions you want and any variables defined in the module
# from test_module import find_index as fi,test # you can also use alias in combination
# from test_module import * # imports everything from the module but tricky to find out which one and debugging

# %%
courses = ['History','Math','Physics','Social Studies']

# %%
# index_fullName=test_module.find_index(courses,'Math') # using full module name
# index_alias=tm.find_index(courses,'Math') #using alias
# index_function=find_index(courses,'Math') #using function from the module
# index_functionAlias = fi(courses,'Math')

# %%
# print(index_fullName)
# print(index_alias)
print(index_function)
# print(index_functionAlias)
print(test)
# Out:
# 1
# Test String

# %%
# How to find out where python searches for the files to be imported if not placed in current working directory
import sys

# %%
print(sys.path)
# Out:
# ['C:\\Program Files\\Python312\\python312.zip', 'C:\\Program Files\\Python312\\DLLs', 'C:\\Program Files\\Python312\\Lib', 'C:\\Program Files\\Python312', '', 'C:\\Users\\ykumar4\\AppData\\Roaming\\Python\\Python312\\site-packages', 'C:\\Users\\ykumar4\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32', 'C:\\Users\\ykumar4\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32\\lib', 'C:\\Users\\ykumar4\\AppData\\Roaming\\Python\\Python312\\site-packages\\Pythonwin', 'C:\\Program Files\\Python312\\Lib\\site-packages']

# %%
# One can add the path where all the scripts are located using environment variables but we can't do that since we aren't admins

# %%
# using standard built in modules
# example random module
import random

# %%
random_choice = random.choice(courses)
print(random_choice)
# Out:
# Math

# %%
random.

# %%
# example math module
import math
rads = math.radians(90)
print(rads)
# Out:
# 1.5707963267948966

# %%
math.pi
# Out:
# 3.141592653589793

# %%
# example datetime and calendar
import datetime
import calendar
today = datetime.date.today()
print(today)
# Out:
# 2025-09-26

# %%
print(calendar.isleap(2020))
# Out:
# True

# %%
# example os module
import os
print(os.getcwd())
print(os.__file__) # Location of the file
# Out:
# C:\Users\ykumar4\AppData\Roaming\Python\Python312\Scripts\PythonClasses
# C:\Program Files\Python312\Lib\os.py

# %%
print(random.__file__)
# Out:
# C:\Program Files\Python312\Lib\random.py
